# %%
# %run main_DDQN.py
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Episode: 0
# 	Score: tensor([-37.6209]), Epsilon: 0.999
#   1%|          | 99/10000 [00:08<13:38, 12.10it/s]
# Episode: 100
# 	Score: tensor([-23.4068]), Epsilon: 0.9038873549665959
#   2%|▏         | 199/10000 [00:17<13:03, 12.51it/s]
# Episode: 200
# 	Score: tensor([-22.5706]), Epsilon: 0.8178301806491574
#   3%|▎         | 300/10000 [00:26<12:25, 13.00it/s]
# Episode: 300
# 	Score: tensor([-12.0494]), Epsilon: 0.7399663251239436
#   4%|▍         | 400/10000 [00:51<41:45,  3.83it/s]
# Episode: 400
# 	Score: tensor([-22.0613]), Epsilon: 0.6695157201007336
#   5%|▌         | 500/10000 [01:18<41:46,  3.79it/s]
# Episode: 500
# 	Score: tensor([-20.8678]), Epsilon: 0.6057725659163237
#   6%|▌         | 600/10000 [01:47<43:34,  3.60it/s]
# Episode: 600
# 	Score: tensor([-13.6222]), Epsilon: 0.548098260578011
#   7%|▋         | 700/10000 [02:17<46:35,  3.33it/s]
# Episode: 700
# 	Score: tensor([-19.0676]), Epsilon: 0.4959150020176678
# ...
