# %%
# %run main_DDQN.py
# Out:
#  20%|██        | 200/1000 [00:38<02:37,  5.07it/s]
# 	Score: tensor([-5.9433]), Epsilon: 0.2436682518625284
#  40%|████      | 400/1000 [01:26<02:33,  3.92it/s]
# 	Score: tensor([4.2706]), Epsilon: 0.05979276633005092
#  60%|██████    | 600/1000 [02:24<01:40,  3.98it/s]
# 	Score: tensor([6.4456]), Epsilon: 0.014672304980531872
#  80%|████████  | 800/1000 [03:27<00:53,  3.76it/s]
# 	Score: tensor([13.6560]), Epsilon: 0.01
# 100%|██████████| 1000/1000 [04:29<00:00,  3.71it/s]
# Epsilon: 0.01
