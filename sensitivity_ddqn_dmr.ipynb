# %%
# %run sensitivity_DDQN_DMR.py
# Out:
# Running with lambd=0.001, sigma=0.2 (default), kappa=1 (default)
# 100%|██████████| 1000/1000 [04:11<00:00,  3.97it/s]
# Epsilon: 0.01
# Running with lambd=0.05, sigma=0.2 (default), kappa=1 (default)
# 100%|██████████| 1000/1000 [04:36<00:00,  3.62it/s]
# Epsilon: 0.01
# Running with lambd=0.1, sigma=0.2 (default), kappa=1 (default)
# 100%|██████████| 1000/1000 [04:24<00:00,  3.79it/s]
# Epsilon: 0.01
# Running with lambd=0.05 (default), sigma=0.01, kappa=1 (default)
# 100%|██████████| 1000/1000 [04:14<00:00,  3.93it/s]
# Epsilon: 0.01
# Running with lambd=0.05 (default), sigma=0.2, kappa=1 (default)
# 100%|██████████| 1000/1000 [05:17<00:00,  3.15it/s]
# Epsilon: 0.01
# Running with lambd=0.05 (default), sigma=0.4, kappa=1 (default)
# 100%|██████████| 1000/1000 [04:22<00:00,  3.82it/s]
# Epsilon: 0.01
# Running with lambd=0.05 (default), sigma=0.2 (default), kappa=0.1
# 100%|██████████| 1000/1000 [04:03<00:00,  4.11it/s]
# Epsilon: 0.01
# ...
