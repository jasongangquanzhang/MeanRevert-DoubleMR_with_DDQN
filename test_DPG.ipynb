# %%
from MR_env_DPG import MR_env
from DMR_env_DPG import DMR_env
from DPG import DPGAgent    
env = MR_env(S_0=1, kappa=1, sigma=0.2, theta=1,
             dt=0.25, T = int(20), gamma=0.99,
             I_max=10, lambd=0.05)
denv = DMR_env(S_0=1, kappa=1, sigma=0.2, theta_a=0.5, theta_b=1.5,
                dt=0.25, T = int(20), 
                I_max=10, lambd=0.05)

agent = DPGAgent(env=denv, gamma=0.99, lr_q=1e-5, lr_p=1e-4, n_layers=6, n_nodes=24, name="test")

# %%
agent.run_strategy(nsims=10)

# %%
agent.train(n_iter=20000, n_plot=2000,mini_batch_size=512, n_iter_Q=1, n_iter_pi=1)
