# %%
# %run main_DDQN_DMR.py
# Out:
#  20%|██        | 200/1000 [00:47<03:14,  4.12it/s]
# 	Score: tensor([-11.5329]), Epsilon: 0.2436682518625284
#  40%|████      | 400/1000 [01:41<02:16,  4.38it/s]
# 	Score: tensor([1.0075]), Epsilon: 0.05979276633005092
#  60%|██████    | 600/1000 [02:34<01:41,  3.93it/s]
# 	Score: tensor([1.4101]), Epsilon: 0.014672304980531872
#  80%|████████  | 800/1000 [03:30<00:53,  3.77it/s]
# 	Score: tensor([10.1858]), Epsilon: 0.01
# 100%|██████████| 1000/1000 [04:30<00:00,  3.69it/s]
# Epsilon: 0.01
