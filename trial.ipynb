# %%
# %run trial.py
# Out:
#  20%|██        | 200/1000 [00:39<02:41,  4.94it/s]
# 	Score: tensor([-8.3584]), Epsilon: 0.2436682518625284
#  40%|████      | 400/1000 [01:48<04:08,  2.41it/s]
# 	Score: tensor([5.2414]), Epsilon: 0.05979276633005092
#  60%|██████    | 600/1000 [03:20<02:56,  2.27it/s]
# 	Score: tensor([3.9650]), Epsilon: 0.014672304980531872
#  80%|████████  | 800/1000 [04:23<00:51,  3.86it/s]
# 	Score: tensor([4.7301]), Epsilon: 0.01
# 100%|██████████| 1000/1000 [05:21<00:00,  3.11it/s]
# Epsilon: 0.01
